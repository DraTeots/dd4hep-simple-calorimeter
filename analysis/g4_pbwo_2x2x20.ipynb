# %%
import uproot
import matplotlib
import matplotlib.pyplot as plt
import awkward as ak
import hist
import numpy as np
from event_display import gdml_read_ecal_info
import os
import pandas as pd
import matplotlib.patches as mpatches
from scipy.stats import crystalball, norm
from epi_analysis import df_make_separation

# %matplotlib inline
matplotlib.rc("figure", dpi=200)

dir_path = os.path.dirname(os.path.realpath("__file__"))
print(f"Believed path is: {dir_path}")
# Out:
# Believed path is: /home/romanov/eic/kak-bog-cherepahu/analysis

# %%
import pandas as pd

all_vals_df = pd.read_feather("/mnt/work/data/epi/21x21/2022_12_05_cherepaha_PbWO4_21x21_20x20x200mm_0.7-18GeV_e-pi-_20kev-each.feather")
all_vals_df["e_div_p"] = all_vals_df.de_sum/(all_vals_df.p*1000)
all_vals_df.head()
epi_title = "E/P SciGlass"

# %%
all_vals_df.groupby("p").mean().index
# Out:
# Float64Index([0.7, 1.0, 2.0, 3.0, 4.0, 6.0, 8.0, 10.0, 12.0, 14.0, 16.0, 18.0], dtype='float64', name='p')

# %%
all_vals_df.groupby("p").mean().e_div_p.plot(style="o--")
# Out:
# <AxesSubplot:xlabel='p'>

# %%
df_make_separation(all_vals_df, 0.7, epi_title)
# Out:
# (0.9956538329534996,
#  0.017714905412894454,
#  0.9602240221277107,
#  19184,
#  0.9592,
#  591,
#  0.02955,
#  816,
#  0.0408,
#  <Figure size 1200x800 with 1 Axes>,
#  <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 0.7 GeV'}, xlabel='(sum modules deposit) / P'>)

# %%
df_make_separation(all_vals_df, 1, epi_title)
# Out:
# (0.9932961947767649,
#  0.016921733300530158,
#  0.9594527281757046,
#  19331,
#  0.96655,
#  268,
#  0.0134,
#  669,
#  0.03345,
#  <Figure size 1200x800 with 1 Axes>,
#  <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 1.0 GeV'}, xlabel='(sum modules deposit) / P'>)

# %%
df_make_separation(all_vals_df, 2, epi_title)
# Out:
# (0.9910324768865101,
#  0.014941650096546962,
#  0.9611491766934162,
#  19385,
#  0.96925,
#  38,
#  0.0019,
#  615,
#  0.03075,
#  <Figure size 1200x800 with 1 Axes>,
#  <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 2.0 GeV'}, xlabel='(sum modules deposit) / P'>)

# %%
df_make_separation(all_vals_df, 6, epi_title)
# Out:
# (0.9876266178051457,
#  0.012508338918788964,
#  0.9626099399675678,
#  19475,
#  0.97375,
#  46,
#  0.0023,
#  525,
#  0.02625,
#  <Figure size 1200x800 with 1 Axes>,
#  <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 6.0 GeV'}, xlabel='(sum modules deposit) / P'>)

# %%
df_make_separation(all_vals_df, 10, epi_title)
# Out:
# (0.9868103401357846,
#  0.010295722044584977,
#  0.9662188960466147,
#  19186,
#  0.9593,
#  22,
#  0.0011,
#  814,
#  0.0407,
#  <Figure size 1200x800 with 1 Axes>,
#  <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 10.0 GeV'}, xlabel='(sum modules deposit) / P'>)

# %%
df_make_separation(all_vals_df, 18, epi_title)
# Out:
# (0.9843668054768524,
#  0.011603122321402636,
#  0.9611605608340471,
#  19380,
#  0.969,
#  32,
#  0.0016,
#  620,
#  0.031,
#  <Figure size 1200x800 with 1 Axes>,
#  <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 18.0 GeV'}, xlabel='(sum modules deposit) / P'>)

# %%
all_momentums = all_vals_df.groupby("p").mean().index

for p in all_momentums:
    data = df_make_separation(all_vals_df, p, epi_title)
    print(data)
# Out:
# (0.9956538329534996, 0.017714905412894454, 0.9602240221277107, 19184, 0.9592, 591, 0.02955, 816, 0.0408, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 0.7 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9932961947767649, 0.016921733300530158, 0.9594527281757046, 19331, 0.96655, 268, 0.0134, 669, 0.03345, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 1.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9910324768865101, 0.014941650096546962, 0.9611491766934162, 19385, 0.96925, 38, 0.0019, 615, 0.03075, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 2.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9894892766245467, 0.013712721225422428, 0.9620638341737018, 19488, 0.9744, 22, 0.0011, 512, 0.0256, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 3.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9888786853158693, 0.011722389686698987, 0.9654339059424714, 19302, 0.9651, 23, 0.00115, 698, 0.0349, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 4.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9876266178051457, 0.012508338918788964, 0.9626099399675678, 19475, 0.97375, 46, 0.0023, 525, 0.02625, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 6.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9869455704709394, 0.01043797228848913, 0.9660696258939612, 19264, 0.9632, 31, 0.00155, 736, 0.0368, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 8.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9868103401357846, 0.010295722044584977, 0.9662188960466147, 19186, 0.9593, 22, 0.0011, 814, 0.0407, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 10.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9856997320926507, 0.01078435711270242, 0.9641310178672459, 19305, 0.96525, 27, 0.00135, 695, 0.03475, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 12.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9853552611147922, 0.012611013970424294, 0.9601332331739436, 19504, 0.9752, 29, 0.00145, 496, 0.0248, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 14.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9849265853518427, 0.011750853641333091, 0.9614248780691765, 19366, 0.9683, 34, 0.0017, 634, 0.0317, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 16.0 GeV'}, xlabel='(sum modules deposit) / P'>)
# (0.9843668054768524, 0.011603122321402636, 0.9611605608340471, 19380, 0.969, 32, 0.0016, 620, 0.031, <Figure size 1200x800 with 1 Axes>, <AxesSubplot:title={'center':'E/P E/P SciGlass <E> = 18.0 GeV'}, xlabel='(sum modules deposit) / P'>)
